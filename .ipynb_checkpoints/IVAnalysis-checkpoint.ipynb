# %% [markdown]
# # IV ANALYSIS

# %%
import sys, os

sys.path.append('../vPDU_analysis/')
from IV_curves import *
from split_data import *
sys.path.append("../vPDU_reco-ana/veto_passport/AnalysisTools")
#sys.path.append("../Experimental_Campaigns/vPDU_spring25")
from IV_curves import load_data, load_setup
import IVAnalysis as IVAnalysis

# %% [markdown]
# ## ----- INPUTS -----

# %%
# ---- INPUTS ----
exp_campaign = 'spring25' #spring25, fall25
batch = 4 #1, 2, 3, 4
temperature = 'warm' #warm, cold
layer = 'top' #top, bottom
configuration = 'quadrants' #quadrants, tiles
date = '01072025' #ddmmyyyy
time_step = '4' #s

save = False
#------------------
#Vbd fitting
Vlow = 15 #15
Vhigh = 85 #80

os.chdir(f'../Experimental_Campaigns/vPDU_{exp_campaign}')

# %% [markdown]
# ### Defining some other patameters

# %%
#Load setup configuration:
tile_groups = ['1', '2', '3', '4']
vpdusQR = load_setup(f'Test_{batch}/setup/vpdu_{layer}.json')

if batch == 1:
    if exp_campaign == 'spring25':
        vpdus = '51_48_98' if layer == 'top' else '92_75_94_65_85'
    else:
        vpdus = '53_97_100_76_48' if layer == 'top' else '92_75_94_65_85'
elif batch == 2:
    vpdus = '98_57_83' if layer == 'top' else '76_103_65_51'
elif batch == 3:
    vpdus = '39_57_83_90' if layer == 'top' else '62_61_81_96_77'
elif batch == 4:
    vpdus = '48_53' if layer == 'top' else '88_94_76_98'

n_vpdus = len(vpdusQR) +1

# ----- LOAD DATA -----
try:
    df = load_data(f'Test_{batch}/{temperature}_tests/Data/IV/IV_{temperature}_{vpdus}_{configuration}_{date}_{time_step}s.csv', n_vpdus, threshold = 40)
    #df = load_data(f'Test_{batch}/{temperature}_tests/Data/IV/IV_{temperature}_{vpdus}_{configuration}_{date}.csv', n_vpdus, threshold = 40)
except FileNotFoundError:
    print('❌ FILE NOT FOUND. Check the date or the time step that has been used.')
    df = load_data(f'Test_{batch}/{temperature}_tests/Data/IV/IV_{temperature}_{vpdus}_{configuration}_{time_step}s.csv', n_vpdus= n_vpdus, threshold = 40)
# Out:
# ❌ FILE NOT FOUND. Check the date or the time step that has been used.
# ⚠️ WARNING: CAEN0_Voltage (V) was not found. This port will be skipped for the analysis.

# %% [markdown]
# # Plot IV curves

# %%
if configuration == 'tiles':
    for i in range(n_vpdus):
        if f'CAEN{i}_Voltage (V)' in df.columns and f'CAEN{i}_Current (uA)' in df.columns:
            plot_tiles(df, f'CAEN{i}_Voltage (V)', f'CAEN{i}_Current (uA)', f"vPDU - {vpdusQR[i]}", save = save, save_path= f'Test_{batch}/{temperature}_tests/Plots/IV_{layer}/IV_{configuration}_{vpdusQR[i]}')
        else:
            print(f"⚠️ WARNING: ({f'CAEN{i}_Voltage (V)'} o {f'CAEN{i}_Current (uA)'}) was not found.")
    
elif configuration == 'quadrants':
    
    for i in range(n_vpdus):
            if f'CAEN{i}_Voltage (V)' in df.columns and f'CAEN{i}_Current (uA)' in df.columns:
                plot_quadrant(df, f'CAEN{i}_Voltage (V)', f'CAEN{i}_Current (uA)', f"vPDU - {vpdusQR[i]}", save=save, save_path=f'Test_{batch}/{temperature}_tests/Plots/IV_{layer}/IV_{configuration}_{vpdusQR[i]}')
            else:
                print(f"⚠️ WARNING: ({f'CAEN{i}_Voltage (V)'} o {f'CAEN{i}_Current (uA)'}) was not found.")
    """
    if 'Tile' not in df.columns:
        print("⚠️ WARNING: 'Tile' column not found, cannot plot quadrants.")
    else:
        for i in range(n_vpdus):
            v_col = f'CAEN{i}_Voltage (V)'
            c_col = f'CAEN{i}_Current (uA)'
            if v_col in df.columns and c_col in df.columns:
                plot_quadrant(df, v_col, c_col, f"vPDU - {vpdusQR[i]}",
                              save=save, save_path=f'Test_{batch}/{temperature}_tests/Plots/IV_{layer}/IV_{configuration}_{vpdusQR[i]}')
            else:
                print(f"⚠️ WARNING: ({v_col} o {c_col}) was not found.")
    """
# Out:
# ⚠️ WARNING: (CAEN0_Voltage (V) o CAEN0_Current (uA)) was not found.

# %% [markdown]
# # Split Data

# %%
for file in os.listdir(f'Test_{batch}/{temperature}_tests/Data/IV/splitted/'):
    if file.endswith(".txt"):
        os.remove(f'Test_{batch}/{temperature}_tests/Data/IV/splitted/' + file)

if layer == 'top':
    split_v2(df, save = save, save_path = f'Test_{batch}/{temperature}_tests/Data/IV/splitted/{layer}/{configuration}')
elif layer == 'bottom' and batch == 2:
    split_v2(df, save = save, save_path = f'Test_{batch}/{temperature}_tests/Data/IV/splitted/{layer}/{configuration}')
else:
    split_v2(df, save = save, save_path = f'Test_{batch}/{temperature}_tests/Data/IV/splitted/{layer}/{configuration}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for file in os.listdir(f'Test_{batch}/{temperature}_tests/Data/IV/splitted/'):
#       2     if file.endswith(".txt"):
#       3         os.remove(f'Test_{batch}/{temperature}_tests/Data/IV/splitted/' + file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Test_4/cold_tests/Data/IV/splitted/'

# %% [markdown]
# # Fit Data

# %%
### !!!!! FIX THIS CELL !!!!! 
def plot_group(file_indices, title, store, Vlim = [Vlow, Vhigh], save = False, save_path = None):
    
    IV = IVAnalysis.IVAnalysis()
    Vbd_Cold = [None] * 4
    Vbd_cold_err = [None] * 4

    plt.figure(figsize=[8, 6])
    for idx in file_indices:
        try:
            Vbd, Vbd_err = IV.calc_Vbd(file[idx], Vstart=Vlim[0], Vstop=Vlim[1], plot_opt=True)
            store.append(Vbd)
            IV.plot_tileIV(file[idx], label=f"Q{idx+1}, {Vbd:.2f} V")
            line = plt.gca().lines[-1]
            plt.axvline(Vbd, color=line.get_color(), linestyle=':', linewidth=3)
            print(f"✅ Q{idx+1}: Vbd = {Vbd:.2f} V ± {Vbd_err:.2f}")
        except Exception as e:
            print(f"❌ Fitting failed for ColdTileIV{idx+1}: {e}")
            store.append(np.nan)
            continue
    plt.xlabel("Voltage [V]")
    plt.ylabel("Current [uA]")
    plt.title(title)
    #plt.xlim(45, 64)
    plt.ylim(2.3, 140)
    #plt.legend()
    if save == True:
        plt.savefig(save_path)
    plt.show()
    #return store

if configuration == 'quadrants':
    file_path = f'Test_{batch}/{temperature}_tests/Data/IV/splitted/{layer}/{configuration}'
    base_path = file_path
    
    file = [os.path.join(base_path, f"IV_q{i}.txt") for i in range(int(4 * n_vpdus))]
    
    plt.rcParams.update({'font.size': 18}) 
    plt.rcParams.update({'lines.linewidth': 3}) 
    plt.rcParams.update({'xtick.direction': 'in'}) 
    plt.rcParams.update({'ytick.direction': 'in'})

    # Plot files 0 to 3 in one figure
    Vbds = []
    for i in range(n_vpdus):
        plot_group(np.linspace(4*i, 4*i+3, 4, dtype = int), title=f"vPDU-{vpdusQR[i]}", store = Vbds, save = False, save_path = f'Test_{batch}/{temperature}_tests/Plots/Vbds/Vbd_{vpdusQR[i]}')

# %% [markdown]
#  ## Breakdown Voltage

# %%
if configuration == 'quadrants':
    for i in range(n_vpdus):
        x = np.linspace(1, 4, 4)
        plt.figure()
        plt.title(f'{vpdusQR[i+1]}')
        plt.plot(x, Vbds[i*4:i*4+4], 'o')
        plt.ylabel('Bd Voltage (V)')
        plt.xlim([0.5,4.5])
        plt.ylim([min(Vbds) - min(Vbds)*0.05, max(Vbds) + max(Vbds)*0.05])

# %%
def svaeVbds(Vbds, filename="salida.txt"):
    if len(Vbds) % 4 != 0:
        raise ValueError("Values missing. Check if all the Vbds had been obtained.")

    arr = np.array(Vbds).reshape(-1, 4)
    np.savetxt(f'Test_{batch}/{temperature}_tests/Data/IV/splitted/{layer}/{configuration}/' + filename, arr)

#svaeVbds(Vbds, filename = 'Vbds.txt' )
